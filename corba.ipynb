# %%
        elif urun == "çorba":
          by = int(input("Baharat istiyorsanız lütfen 1'e , baharat istemiyorsanız lütfen 0'a basın."))
          if by == 1:
              baharat = input("Lütfen baharatı giriniz:")
              print(f"{baharat} ekleniyor")
          elif by == 0:
            continue
#baharat yerini değiştir
cmenu = (""" ------MENU--------
      1. Mercimek 
      2. Yayla Çorbası
      3. Tarhana Çorbası """)
cmenusozluk = {"1" :['Mercimek', 10], "2" : ["Yayla Çorbası" , 12], "3" :[ "Tarhana Çorbası" , 15]}
        elif urun == "çorba":
            x =  int(input("Lütfen kac adet çorba siparis edeceginizi giriniz: "))
            print(cmenu)
            for c in range(x):
              alınan = input("Lutfen {} numarali sıparısinizi gırınız" .format(c+1) )
              if alınan == "1":
                corba =Çorba(isim=cmenusozluk[(alınan)][0], fiyat= cmenusozluk[alınan][0])
                corba.alınan()
              elif alınan =="2":
                corba =Çorba(isim=cmenusozluk[(alınan)][0], fiyat= cmenusozluk[alınan][0])
                corba.alınan()
              elif alınan == "3":
                corba =Çorba(isim=cmenusozluk[(alınan)][0], fiyat= cmenusozluk[alınan][0])
                corba.alınan()


mmenu = (""" ------MENU--------
      1. Spagetti  
      2. kelebek makarna
      3.  boncuk makarna """)
mmenusozluk = {"1" :['Spagetti', 10], "2" : ["Kelebek" , 12], "3" :[ "Boncuk makarna" , 15]}
#sos menüsü girelilm mi 
        elif urun == "makarna":
          sos = input("Lütfen sos giriniz:")
          print(f"{sos} ekleniyor")
            y =  int(input("Lütfen kac adet makarna siparis edeceginizi giriniz: "))
            print(cmenu)
            for b in range(y):
              istenen = input("Lutfen {} numarali sıparısinizi gırınız" .format(b+1) )
              if alınan == "1":
                makarna =Makarna(isim=cmenusozluk[(istenen)][0], fiyat= cmenusozluk[istenen][0])
                makarna.istenen()
              elif istenen =="2":
                corba =Çorba(isim=cmenusozluk[(istenen)][0], fiyat= cmenusozluk[istenen][0])
                makarna.istenen()
              elif istenen == "3":
                corba =Çorba(isim=cmenusozluk[(istenen)][0], fiyat= cmenusozluk[istenen][0])
                makarna.istenen()


imenu = (""" ------MENU--------
      1. Nohutlu Pilav  
      2. Tavuklu Pilav
      3.  Bulgur Pilavı """)
imenusozluk = {"1" :['Nohutlu Pilav', 40], "2" : ["Tavuklu Pilav" , 40], "3" :[ "Bulgur Pilavı" , 40]}
        elif urun == "pilav":
            s =  int(input("Lütfen kac adet pilav siparis edeceginizi giriniz: "))
            print(cmenu)
            for a in range(s):
              ilgili = input("Lutfen {} numarali sıparısinizi gırınız" .format(a+1) )
              if alınan == "1":
                pilav =Pilav(isim=imenusozluk[(ilgili)][0], fiyat= cmenusozluk[ilgili][0])
                pilav.ilgili()
              elif istenen =="2":
                corba =Çorba(isim=imenusozluk[(ilgili)][0], fiyat= cmenusozluk[ilgili][0])
                pilav.ilgili()
              elif istenen == "3":
                corba =Çorba(isim=imenusozluk[(ilgili)][0], fiyat= cmenusozluk[ilgili][0])
                pilav.ilgili()

class Menu:
  def __init__(self,isim,fiyat):
    self.isim = isim
    self.fiyat = fiyat
    self.icindekiler = icindekiler
class Icecek(Menu):
    def __init__(self, isim, fiyat, icindekiler):
      super().__init__(isim, fiyat, icindekiler, boyut)
      self.boyut = boyut
    def Boyut(self):
      b = input("Lütfen içeceğinizin boyutunu giriniz: ")
      print(f"{b} boyutundaki {self.isim} adındaki siparişiniz alındı.")

icecek = (""" ------MENU--------
      1. Coca Cola  
      2. Ayran
      3. Ice Tea
      4. Fanta
      5. Meyve Suyu """)

imenusozluk = {"1" :['Coca Cola', 20], "2" : ["Ayran" , 10], "3" :[ "Ice Tea" , 40], "4" : ["Fanta" , 15], "5" : ["Meyve Suyu", 10]}
ic =  int(input("Lütfen kac adet içecek siparis edeceginizi giriniz: "))
print(icecek)
for w in range(ic):
  ilgili = input("Lutfen {} numarali sıparısinizi gırınız" .format(a+1) )
    if alınan == "1":
      icmek =icecek(isim=imenusozluk[(ilgili)][0], fiyat= imenusozluk[ilgili][1])
      icmek.Boyut()
      elif istenen =="2":
        icmek =icecek(isim=imenusozluk[(ilgili)][0], fiyat= imenusozluk[ilgili][1])
        icmek.Boyut()
      elif istenen == "3":
        icmek =icecek(isim=imenusozluk[(ilgili)][0], fiyat= imenusozluk[ilgili][1])
        icmek.Boyut()

# %%
print(mmenu)
