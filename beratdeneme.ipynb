# %% [markdown]
# fiyatlarda ortak karar alalim
# index tekrar degisecek 01 yerine margarita (serra)
# dosya yazdirma (berat)
# odeme bolumune eklemeler para ustu hesaplama etc. (alican)
# indirim gunu if gun = sali, toplam fiyat uzerinden %20 indirim (alican)
# rastgele tatli ekleme (alican) - sans oyunuyla olasilik 1 gelirse tatli...

# %%
print("Restorana hosgeldiniz")
import time
import datetime
import pandas as pd
menu = pd.DataFrame({"Yemekler": ["Pizza","Makarna","Çorba","Pilav"],
                     "Çeşit : 1" : ["Margarita Pizza: 50 TL","Spagetti Makarna: 17 TL","Mercimek: 10 TL","Tavuklu Pilav: 21 TL"],
                     "Çeşit : 2" : ["Etli Pizza: 40 TL", "Kelebek Makarna: 15 TL","Yayla Çorbası: 10 TL","Bulgur Pilavı: 21 TL"],
                     "Çeşit : 3" : ["Veggie Pizza: 40 TL","Boncuk Makarna: 14 TL","Tarhana Çorbası: 14 TL","Nohutlu Pilav: 17 TL"]})
print(menu)
menu_icecek = pd.DataFrame({"İçecekler" : ["Coco Cola","Fanta","IceTea","Meyve Suyu","Ayran"],
                                           "Fiyat" : [20,18,17,35,15]})
print(menu_icecek)
toplam_fiyat = 0

class Menu:
  def __init__(self,isim,fiyat ):
    self.isim = isim
    self.fiyat = fiyat

class Pizza(Menu):
    def __init__(self, isim, fiyat, icindekiler,boy,kenar,sos):
      super().__init__(isim, fiyat)
      self.icindekiler = icindekiler
      self.boy = boy
      self.kenar = kenar
      self.sos = sos
    def SiparisGoster(self):
        print(f" Sipariş: {self.isim}, Fiyat:{self.fiyat}, İçindekiler: {self.icindekiler}, Sosu: {self.sos}")


    def siparis(self):
        s = input("siparişinizde değişiklik yapmak istiyor musunuz: ").lower()
        if s == "evet":
            e = input(("Eklemek ıstedıgınız urun: ")).lower()
            c = input(("Cıkartmak ıstedıgınız urun: ")).lower()
            if e == "yok":
                pass
            else:       
                self.icindekiler.append(e)
                print("ozel isteginiz kaydedildi")
            if c == "yok":
                pass
            else: 
                self.icindekiler.remove(c)
                print("ozel isteginiz kaydedildi")
        
  
  
class Çorba(Menu):
    def __init__(self, isim, fiyat):
      super().__init__(isim, fiyat)
    def SiparisGoster(self):
      print(f"Sipariş: {self.isim}, Fiyat:{self.fiyat}, Baharat : {baharat}")

class Makarna(Menu):
    def __init__(self, isim, fiyat):
      super().__init__(isim, fiyat)

    def SiparisGoster(self):
        print(f"Sipariş: {self.isim}, Sos: {sos} Fiyat:{self.fiyat}")           

class Pilav(Menu):
    def __init__(self, isim, fiyat,cesit):
      super().__init__(isim, fiyat )
      self.cesit = cesit
    def SiparisGoster(self):
        print(f"Sipariş: {self.isim}, Cesit: {self.cesit} Fiyat:{self.fiyat}")

class Icecek(Menu):
    def _init_(self, isim, fiyat):
      super()._init_(isim, fiyat )
    def SiparisGoster(self):
      print(f"Sipariş: {self.isim}, Boyut: {b} Fiyat:{self.fiyat}")

margarita= 0
veggi = 0
etli=0
mercimek= 0
yayla= 0
tarhana= 0
spagetti =0
kelebek= 0
boncuk=0
nohutlu=0
tavuklu=0
bulgur=0
cola=0
ayran=0
icetea=0
fanta=0
meyvesuyu=0



l1 = ["mozarella", "domates"]
l2 = ["mozarella", "domates", "biber", "patlican"]
l3 = ["mozarella", "domates", "sucuk"]
menusozluk = {'01': ['Margarıta', 50, l1], "02" : ["EtliPizza" , 40,l2], "03" :[ "VeggiePizza" , 40, l3], #hepsini duzelt
"11" :['Spagetti', 17], "12" : ["Kelebek" , 15], "13" :[ "Boncuk" , 14],
"21" :['Mercimek', 10], "22" : ["Yayla" , 10], "23" :[ "Tarhana" , 14],
"31" :['Tavuklu', 21], "32" : ["Bulgur" , 21], "33" :[ "Nohut" , 17]}
imenusozluk = {"01" :['Coca Cola', 20], "11" : ["Ayran" , 10], "21" :[ "Ice Tea" , 40], "31" : ["Fanta" , 15], "41" : ["Meyve Suyu", 10]}
siparisler = []
while True:
    
        urun = input("Sipariş etmek istediğiniz urunu girin: (Pizza,Makarna,Çorba,Pilav,İçecek) " ).lower()
        if urun == "pizza":
           
            sayi = int(input("Lütfen kac adet pizza siparis edeceginizi giriniz: "))
            
            for i in range(sayi):
              siparis = input("Lutfen {} numarali sıparısinizi gırınız" .format(i+1) )
              boy =input("Lütfen boyutunu giriniz:")
              kenar = input("Lütfen kenarı giriniz:")
              sos = input("Lutfen sos giriniz: ")
              if siparis == '01':
                margarita +=1
                pizza = Pizza(isim= menusozluk[(siparis)][0], fiyat = menusozluk[(siparis)][1] , icindekiler=menusozluk[(siparis)][2] , boy = boy, kenar = kenar, sos = sos)
                print("Icındekıler: ", l1)
                pizza.siparis()
                pizza.SiparisGoster()
                siparisler.append(siparis)
                siparisler.append(str(menusozluk[siparis][1]))
                toplam_fiyat += menusozluk[siparis][1]
                print("-"*40)

              elif siparis == '02':
                etli +=1
                pizza = Pizza(isim= menusozluk[(siparis)][0], fiyat = menusozluk[(siparis)][1] , icindekiler=menusozluk[(siparis)][2] , boy = boy, kenar = kenar, sos = sos)
                print("Icındekıler: ", l2)
                pizza.siparis()
                pizza.SiparisGoster()
                siparisler.append(siparis)
                siparisler.append(str(menusozluk[siparis][1]))
                toplam_fiyat += menusozluk[siparis][1]
                print("-"*40)
            
              elif siparis == '03':
                veggi +=1
                pizza = Pizza(isim= menusozluk[(siparis)][0], fiyat = menusozluk[(siparis)][1] , icindekiler=menusozluk[(siparis)][2] , boy = boy, kenar = kenar, sos = sos)
                print("Icındekıler: ", l3)
                pizza.siparis()  
                pizza.SiparisGoster()
                siparisler.append(siparis)
                siparisler.append(str(menusozluk[siparis][1]))
                toplam_fiyat += menusozluk[siparis][1]
                print("-"*40)


        elif urun == "corba":
          print("06.00-12.00 arasında çorba servisimiz vardır, maalesef bu saatler dışında servis yoktur")
          try:
            now = datetime.datetime.now() 
             
            if 6 <= now.hour < 12:
               print(f"Saat : {now.hour}.00 , {urun} serivisi vardır.")
               x =  int(input("Lütfen kac adet çorba siparis edeceginizi giriniz: "))
               
               for c in range(x):
                siparis = input(f"Lutfen {c+1} numarali sıparısinizi gırınız" )
                by = int(input("Baharat istiyorsanız lütfen 1'e , baharat istemiyorsanız lütfen 0'a basın."))
               if by == 1:
                  baharat = input("Lütfen baharatı giriniz:")
                  print(f"{baharat} ekleniyor")
               elif by == 0:
                  pass
               corba =Çorba(isim=menusozluk[(siparis)][0], fiyat= menusozluk[siparis][1])
               corba.SiparisGoster()
               siparisler.append(corba.SiparisGoster)
               toplam_fiyat += menusozluk[siparis][1]
               print("-"*40)
            else:
               print(f"Saat : {now.hour}.{now.minute}, {urun} servisi yoktur.")
               pass
          except Exception as e:
            print(f"{urun} servisinde bir hata oluştu ve sebebi:{e}")
                        if siparis == "11":
                           mercimek +=1
                        elif siparis == "12":
                           yayla +=1
                        elif siparis == "13":
                           tarhana += 1      


        elif urun == "makarna":
          
          adet =  int(input("Lütfen kac adet makarna siparis edeceginizi giriniz: "))
          
          for b in range(adet):
            siparis = input("Lutfen {} numarali sıparısinizi gırınız" .format(b+1) )
            sos = input("Lütfen sos giriniz:").lower()
            print(f"{sos} ekleniyor")
            makarna =Makarna(isim=menusozluk[(siparis)][0], fiyat= menusozluk[siparis][1])
            makarna.SiparisGoster()
            siparisler.append(makarna.SiparisGoster)
            toplam_fiyat += menusozluk[siparis][1]
            print("-"*40)

            if siparis == "21":
              spagetti += 1
            elif siparis == "22":
              kelebek += 1
            elif siparis == "23":
              boncuk += 1 

        elif urun == "pilav":
            s =  int(input("Lütfen kac adet pilav siparis edeceginizi giriniz: "))
           
            for a in range(s):
              siparis = input("Lutfen {} numarali sıparısinizi gırınız" .format(a+1) )
              pilav =Pilav(isim=menusozluk[(siparis)][0], fiyat= menusozluk[siparis][1], cesit =menusozluk[(siparis)][0] )
              pilav.SiparisGoster()
              siparisler.append(pilav.SiparisGoster)
              toplam_fiyat += menusozluk[siparis][1]
              print("-"*40)

              if siparis == "9":
                nohutlu +=1
              elif siparis == "10":
                tavuklu +=1
              elif siparis == "11":
                bulgur += 1

        elif urun == "icecek":
         ic =  int(input("Lütfen kac adet içecek siparis edeceginizi giriniz: "))
         for w in range(ic):
            siparis = input("Lutfen {} numarali sıparısinizi gırınız" .format(w+1) )
            b = input("Lütfen içeceğinizin boyutunu giriniz: ")
            
            icecek = Icecek(isim=imenusozluk[(siparis)][0], fiyat= imenusozluk[siparis][1])
            icecek.SiparisGoster()
            siparisler.append(icecek.SiparisGoster)
            toplam_fiyat += imenusozluk[siparis][1]
            print("-"*40)
            
            if siparis == "12":
              cola +=1
            elif siparis == "13":
              ayran +=1
            elif siparis == "14":
              icetea +=1
            elif siparis == "15":
              fanta +=1
            elif siparis == "16":
              meyvesuyu +=1
                
        else:
            print("girdiğiniz ürün yoktur, lütfen tekrar seçiniz")
            continue
        
        
        urun_ekleme = input("başka bir urun eklemek istiyor musunuz: (Evet-Hayır)").lower()
        if urun_ekleme == "evet":
            continue
        else:
            pass
        kontrol = input("Yaptığınız işlemler doğru mu? (Evet-Hayır)").lower()
        if kontrol == "evet":
            break

isim = input("Isminizi giriniz: ")
soyisim = input("soyisminizi giriniz")
print("Toplam fiyat: ", toplam_fiyat)
tur = input("Lütfen ödeme türünüzü seçiniz. Kart mı? Nakit mi?").lower()
if tur == "nakit":
    print("Ödemeniz nakit alınacaktır.")
elif tur == "kart":
    print("Ödemeniz karttan alınacaktır.")




with open("fis.txt", "w+", encoding = "utf-8") as f: #deneme.txt dosyasında pizza ve diğer ürünlerin maliyetini varsayım şeklinde girebiliriz. Çünkü her ürünün farklı işletmelere maliyeti farklı olur.
    f.write("*"*20)
    f.write(str(time.ctime(time.time())))
    f.write("\n")
    f.write("RESTORAN FISI")
    f.write("\n")
    f.write(f"Isim:{isim} ")
    f.write("\n")
    f.write(f"Soyisim: {soyisim}")
    f.write("\n")
    f.writelines(siparisler)
    f.write("\n")
    f.write(f"Toplam fiyat: {toplam_fiyat} ")
    f.write("\n")
    f.write(f"Odeme turu: {tur}")
    f.write("\n")
    f.write("*"*20) 

with open("fis.txt", "w+", encoding = "utf-8") as f: #deneme.txt dosyasında pizza ve diğer ürünlerin maliyetini varsayım şeklinde girebiliriz. Çünkü her ürünün farklı işletmelere maliyeti farklı olur.
    lines = [f""*"*20\n str(time.ctime(time.time()))\n RESTORANT FİŞİ\n İsim: {isim} Soyisim:{soyisim}\n siparisler\n ToplamFiyat: {toplam_fiyat}\n ÖdemeTürü: {tur}\n "*"*20"] 
    f.writelines(lines)

with open ("restorant.txt", "w+", encoding = "utf-8") as res: #w+ dogru mu kontrol edelim, surekli ustune eklemesi gerekiyor her seferinde yeniden baslamasi degil
   lines = [f"GÜNLÜK YAPILAN SATIŞLAR\n Margarita : {margarita}\n VeggiePizza: {veggie}\n EtliPizza: {etli}\n Mercimek: {mercimek}\n Yayla Çorbası: {yayla}\n Tarhana Çorbası: {tarhana}\n Spagetti Makarna: {spagetti}\n Kelebek Makarna: {kelebek}\n Boncuk Makarna: {boncuk}\n Nohutlu Pilav: {nohutlu}\n Tavuklu Pilav: {tavuklu}\n Bulgur Pilavı: {bulgur}\n Coca Cola: {cola}\n Ayran: {ayran}\n IceTea: {icetea}\n Fanta: {fanta}\n MeyveSuyu: {meyvesuyu}\n" ]
   res.writelines(lines)

# %%
 margaritag = 40 #Margarita pizzanın gideri
 veggieg = 30
 etlig = 30
 mercimekg = 7
 yaylag = 8
 tarhaang= 10
 spagettig= 12
 kelebekg= 10
 boncukg = 9
 nohutg= 13
 tavuklu = 17
 bulgurg= 15
 colag = 10
 ayrang = 7
 icetg = 12
 fantag = 13
 meyves = 20

 margaritaa = 50 #Margarita pizzanın satış fiyatı
 veggiea = 40
 etlia = 40
 mercimeka = 10
 yaylaa = 10
 tarhaana= 14
 spagettia= 17
 kelba= 15
 boncuka = 14
 nohuta= 17
 tavuklua = 21
 bulgura= 21
 colaa = 20
 ayrana = 15
 icet = 17 
 fantaa = 18
 meyve = 35

gunluk_kazanc = [[{margaritaa}*{margarita} - {margaritag}*{margarita}] + [{veggiea}*{veggie} - {veggieg}*{veggie}] + [{etlia}*{etli} - {etlig}*{etli}] + [{mercimeka}*{mercimek} - {mercimekg}*{mercimek}]+ [{yaylaa}*{yayla} - {yaylag}*{yayla}] + [{tarhaana}*{tarhana} - {tarhaang}*{tarhana}] + [{spagettia}*{spagetti} - {spagettig}*{spagetti}]
                  + [{kelba}*{kelebek} - {kelebekg}*{kelebek}] + [{boncuka}*{boncuk} - {boncukg}*{boncuk}] + [{nohuta}*{nohutlu} - {nohutg}*{nohutlu}] + [{tavuklua}*{tavuklu} - {tavuklu}*{tavuklu}] + [{bulgura}*{bulgur} - {bulgurg}*{bulgur}] + [{colaa}*{cola} - {colag}*{cola}] 
                  + [{ayrana}*{ayran} - {ayrang}*{ayran}] + [{icet}*{icetea} - {icetg}*{icetea}] + [{fantaa}*{fanta} - {fantag}*{fanta}]+ [{meyve}*{meyvesuyu}- {meyves}*{meyvesuyu}]]


kira = int(input("Lütfen kiranızı giriniz:"))
faturalar = int(input("Lütfen faturalarınızın tutarını giriniz:"))
ascı = int(input("Lütfen aşçınızın maaşını giriniz:"))
garson = int(input("Lütfen garsonun maaşını giriniz:"))
alısveris = int(input("Lütfen işletmeniz için yaptığınız alımların ücretini giriniz:"))


aylık_kazanc = [[{günlük_kazanc} *30] - [ kira + ascı + garson+ faturalar + alısveris]]


with open ("restorant.txt", "w+", encoding = "utf-8") as res: #w+ dogru mu kontrol edelim, surekli ustune eklemesi gerekiyor her seferinde yeniden baslamasi degil
   lines = [f"GÜNLÜK YAPILAN SATIŞLAR\n Margarita : {margarita}\n VeggiePizza: {veggie}\n EtliPizza: {etli}\n Mercimek: {mercimek}\n Yayla Çorbası: {yayla}\n Tarhana Çorbası: {tarhana}\n Spagetti Makarna: {spagetti}\n Kelebek Makarna: {kelebek}\n Boncuk Makarna: {boncuk}\n Nohutlu Pilav: {nohutlu}\n Tavuklu Pilav: {tavuklu}\n Bulgur Pilavı: {bulgur}\n Coca Cola: {cola}\n Ayran: {ayran}\n IceTea: {icetea}\n Fanta: {fanta}\n MeyveSuyu: {meyvesuyu}\n GİDERLER\n Kira: {kira}\n ÇalışanÜcretleri: {garson +ascı}\n Faturalar: {faturalar}\n Alışveriş:{alısveris} AylıkKazanç: {aylık_kazanc}\n" ]
   res.writelines(lines)

# %%
import pandas as pd

soru = input("Geri bildirim anketimize katılmak ister misiniz? ")

#if soru == "hayır":
 # return print("İyi günler dileriz")

if soru == "evet":
  yemekler = int(input("Lütfen yemeklerimizi beş üzerinden değerlendiriniz: "))
  servis = int(input("Lütfen servisimizi beş üzerinden değerlendiriniz: "))
  restorant= int(input("Lütfen restorantımızı beş üzerinden değerlendiriniz: "))
  print("Geri dönüş sağladığınız için teşekkür eder, iyi günler dileriz.")
data= {"Yemekler": [{yemekler}],
        "Servis" : [{servis}],
        "restorant": [{restorant}]}

df = pd.DataFrame(data)
df.to_excel("C:\\Users\\ADA\\Desktop\\samurai.xlsx")
