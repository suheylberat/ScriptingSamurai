# %%
import time
import datetime
import pandas as pd
import random
print("Restorantımıza hoş geldiniz")
menu = pd.DataFrame({"Yemekler": ["Pizza","Makarna","Çorba","Pilav"],
                     "Çeşit : 1" : ["Margarita: 50 TL","Spagetti: 17 TL","Mercimek: 10 TL","Tavuklu: 21 TL"],
                     "Çeşit : 2" : ["Etli: 40 TL", "Kelebek: 15 TL","Yayla: 10 TL","Bulgur: 21 TL"],
                     "Çeşit : 3" : ["Veggie: 40 TL","Boncuk: 14 TL","Tarhana: 14 TL","Nohutlu: 17 TL"]})
print(menu)
print("-"*40)
menu_icecek = pd.DataFrame({"İçecekler" : ["Coco Cola","Fanta","IceTea","Meyve Suyu","Ayran"],
                                           "Fiyat" : [20,18,17,35,15]})
print(menu_icecek)
toplam_fiyat = 0

class Menu:
  def __init__(self,isim,fiyat ):
    self.isim = isim
    self.fiyat = fiyat

class Pizza(Menu):
    def __init__(self, isim, fiyat, icindekiler,boy,kenar,sos):
      super().__init__(isim, fiyat)
      self.icindekiler = icindekiler
      self.boy = boy
      self.kenar = kenar
      self.sos = sos
    def SiparisGoster(self):
        print(f" Sipariş: {self.isim}, Fiyat:{self.fiyat}, İçindekiler: {self.icindekiler}, Sosu: {self.sos}")


    def siparis(self):
        s = input("siparişinizde değişiklik yapmak istiyor musunuz: ").lower()
        if s == "evet":
            e = input(("Eklemek istediğiniz urun: ")).lower()
            c = input(("Çıkartmak istediğiniz urun: ")).lower()
            if e == "yok":
                pass
            else:       
                self.icindekiler.append(e)
                print("Özel isteğiniz kaydedildi.")
            if c == "yok":
                pass
            else: 
                self.icindekiler.remove(c)
                print("Özel isteğiniz kaydedildi.")
        
  
  
class Çorba(Menu):
    def __init__(self, isim, fiyat):
      super().__init__(isim, fiyat)
    def SiparisGoster(self):
      print(f"Sipariş: {self.isim}, Fiyat:{self.fiyat}, Baharat : {baharat}")

class Makarna(Menu):
    def __init__(self, isim, fiyat):
      super().__init__(isim, fiyat)

    def SiparisGoster(self):
        print(f"Sipariş: {self.isim}, Sos: {sos} Fiyat:{self.fiyat}")           

class Pilav(Menu):
    def __init__(self, isim, fiyat,cesit):
      super().__init__(isim, fiyat )
      self.cesit = cesit
    def SiparisGoster(self):
        print(f"Sipariş: {self.isim}, Çesit: {self.cesit} Fiyat:{self.fiyat}")

class Icecek(Menu):
    def _init_(self, isim, fiyat):
      super()._init_(isim, fiyat )
    def SiparisGoster(self):
      print(f"Sipariş: {self.isim}, Boyut: {b} Fiyat:{self.fiyat}")

margarita= 0
veggi = 0
etli=0
mercimek= 0
yayla= 0
tarhana= 0
spagetti =0
kelebek= 0
boncuk=0
nohutlu=0
tavuklu=0
bulgur=0
cola=0
ayran=0
icetea=0
fanta=0
meyvesuyu=0



l1 = ["mozarella", "domates"]
l2 = ["mozarella", "domates", "biber", "patlıcan"]
l3 = ["mozarella", "domates", "sucuk"]
menusozluk = {'margarita': [50, l1], "etli" : [40,l2], "veggie" : [40, l3], #hepsini duzelt
'spagetti' : 17, "kelebek" : 15,  "boncuk" : 14,
'sercimek': 10, "yayla" : 10, "tarhana" : 14,
'tavuklu': 21, "bulgur" : 21,  "nohutlu" : 17}
imenusozluk = {'cocacola': 20, "ayran" : 10, "icetea" : 40, "fanta" : 15, "meyvesuyu": 10}
siparisler = []
while True:
    
        urun = input("Sipariş etmek istediğiniz ürünü girin: (Pizza,Makarna,Çorba,Pilav,İçecek) " ).lower()
        if urun == "pizza":
           
            sayi = int(input("Lütfen kac adet pizza sipariş edeceğinizi giriniz: "))
            
            for i in range(sayi):
              siparis = input("Lütfen pizzanızı seçiniz (margarita, etlipizza, veggiepizza), boşluk bırakmayınız" .format(i+1) )
              boy =input("Lütfen boyutunu giriniz:")
              kenar = input("Lütfen kenarını giriniz:")
              sos = input("Lütfen sos giriniz: ")
              if siparis == 'margarita':
                margarita +=1
                pizza = Pizza(isim= siparis, fiyat = menusozluk[siparis][0] , icindekiler=menusozluk[siparis][1] , boy = boy, kenar = kenar, sos = sos)
                print("İçindekiler: ", l1)
                pizza.siparis()
                pizza.SiparisGoster()
                siparisler.append(siparis)
                siparisler.append(menusozluk[siparis][0])
                toplam_fiyat += menusozluk[siparis][0]
                print("-"*40)

              elif siparis == 'etli':
                etli +=1
                pizza = Pizza(isim= siparis, fiyat = menusozluk[siparis][0] , icindekiler=menusozluk[siparis][1] , boy = boy, kenar = kenar, sos = sos)
                print("İçindekiler: ", l2)
                pizza.siparis()
                pizza.SiparisGoster()
                siparisler.append(siparis)
                siparisler.append(menusozluk[siparis][0])
                toplam_fiyat += menusozluk[siparis][0]
                print("-"*40)
            
              elif siparis == 'veggie':
                veggi +=1
                pizza = Pizza(isim= siparis, fiyat = menusozluk[siparis][0] , icindekiler=menusozluk[siparis][1] , boy = boy, kenar = kenar, sos = sos)
                print("İçindekiler: ", l3)
                pizza.siparis()  
                pizza.SiparisGoster()
                siparisler.append(siparis)
                siparisler.append(menusozluk[siparis][0])
                toplam_fiyat += menusozluk[siparis][0]
                print("-"*40)


        elif urun == "corba":
          print("06.00-12.00 arasında çorba servisimiz vardır, maalesef bu saatler dışında servis yoktur")
          try:
            now = datetime.datetime.now() 
             
            if 6 <= now.hour < 12:
               print(f"Saat : {now.hour}.00 , {urun} servisi vardır.")
               x =  int(input("Lütfen kaç adet çorba sipariş edeceğinizi giriniz: "))
               
               for c in range(x):
                siparis = input(f"Lütfen çorba seçiminizi giriniz (mercimek,yayla,tarhana): " )
                if siparis == "mercimek":
                  mercimek +=1
                elif siparis == "yayla":
                  yayla +=1
                elif siparis == "tarhana":
                  tarhana += 1   
                by = int(input("Baharat istiyorsanız lütfen 1'e , baharat istemiyorsanız lütfen 0'a basın."))
               if by == 1:
                  baharat = input("Lütfen baharatı giriniz:")
                  print(f"{baharat} ekleniyor")
               elif by == 0:
                  pass
               corba =Çorba(isim=siparis, fiyat= menusozluk[siparis])
               corba.SiparisGoster()
               siparisler.append(siparis)
               siparisler.append(menusozluk[siparis])
               toplam_fiyat += menusozluk[siparis]
               print("-"*40)
            else:
               print(f"Saat : {now.hour}.{now.minute}, {urun} servisi yoktur.")
               pass
          except Exception as e:
            print(f"{urun} servisinde bir hata oluştu ve sebebi:{e}")
           


        elif urun == "makarna":
          
          adet =  int(input("Lütfen kaç adet makarna sipariş edeceğinizi giriniz: "))
          
          for b in range(adet):
            siparis = input("Lütfen makarna siparişinizi giriniz (spagetti, kelebek, boncuk)" .format(b+1) )
            sos = input("Lütfen sos giriniz:").lower()
            if sos == "yok":
               continue
            else:
              print(f"{sos} ekleniyor")
            makarna =Makarna(isim=siparis, fiyat= menusozluk[siparis])
            makarna.SiparisGoster()
            siparisler.append(siparis)
            siparisler.append(menusozluk[siparis])
            toplam_fiyat += menusozluk[siparis]
            print("-"*40)

            if siparis == "spagetti":
              spagetti += 1
            elif siparis == "kelebek":
              kelebek += 1
            elif siparis == "boncuk":
              boncuk += 1 

        elif urun == "pilav":
            s =  int(input("Lütfen kaç adet pilav sipariş edeceğinizi giriniz: "))
           
            for a in range(s):
              siparis = input("Lütfen pilav siparisinizi giriniz (nohutlu, tavuklu, bulgur)" .format(a+1) )
              pilav =Pilav(isim=siparis, fiyat= menusozluk[siparis], cesit =siparis )
              pilav.SiparisGoster()
              siparisler.append(siparis)
              siparisler.append(menusozluk[siparis])
              toplam_fiyat += menusozluk[siparis]
              print("-"*40)

              if siparis == "nohutlu":
                nohutlu +=1
              elif siparis == "tavuklu":
                tavuklu +=1
              elif siparis == "bulgur":
                bulgur += 1

        elif urun == "icecek":
         ic =  int(input("Lütfen kaç adet içecek sipariş edeceğinizi giriniz: "))
         for w in range(ic):
            siparis = input("Lutfen icecek siparisinizi giriniz (cocacola, ayran, icetea, fanta, meyvesuyu)" .format(w+1) )
            b = input("Lütfen içeceğinizin boyutunu giriniz: ")
            
            icecek = Icecek(isim=siparis, fiyat= imenusozluk[siparis])
            icecek.SiparisGoster()
            siparisler.append(siparis)
            siparisler.append(imenusozluk[siparis])
            toplam_fiyat += imenusozluk[siparis]
            print("-"*40)
            
            if siparis == "cocacola":
              cola +=1
            elif siparis == "ayran":
              ayran +=1
            elif siparis == "icetea":
              icetea +=1
            elif siparis == "fanta":
              fanta +=1
            elif siparis == "meyvesuyu":
              meyvesuyu +=1
                
        else:
            print("Girdiğiniz ürün yoktur, lütfen tekrar seçiniz. ")
            continue
        
        
        urun_ekleme = input("başka bir ürün eklemek istiyor musunuz: (Evet-Hayır)").lower()
        if urun_ekleme == "evet":
            continue
        else:
            pass
        kontrol = input("Yaptığınız işlemler doğru mu? (Evet-Hayır)").lower()
        if kontrol == "evet":
            break

isim = input("İsminizi ve Soyisminizi giriniz: ")
print("Toplam fiyat: ", toplam_fiyat)
print("-"*40)

tatlilar = ["Baklava","İrmik helvası","Şekerpare","Künefe","Profiterol","Kazandibi","Lokum","Kadayıf","Trileçe","Çikolatalı lava kek"]
sansizlik = [0,0,0]
tatli_ikram_sansi = tatlilar + sansizlik
sonuc = random.choice(tatli_ikram_sansi)
print("Sizi bir sürprizimiz ile tanıştırıyoruz, eğer şanslıysanız size tatlı ikram edeceğiz")
time.sleep(5)

if sonuc == 0:
   print("Bugün şansınızı başka bir yerde kullandınız herhalde, maalesef tatlı alma şansını kaybettiniz.")
else:
   print(f"Tebrikler tatlı almaya hak kazandınız ve tatlınız : {sonuc}'dır")
print("-"*40)
for i in range(5,35,5):
  if datetime.datetime.now().day == i :
    print("Sizi bir sürprizimiz ile daha tanıştırıyoruz, Bizi her ayın 5.,10.,15.,20.,25. ve 30. günlerinde tercih ederseniz ki siz ettiniz %20 tüm ürünlerde indirim yaparak uğurluyoruz")
    print(f"Normalde toplam fiyat: {toplam_fiyat}")
    toplam_fiyat = toplam_fiyat*80/100
    print(f"Bugüne özel Toplam Fiyat : {toplam_fiyat}")
  else:
    pass

print("-"*40)
tur = input("Lütfen ödeme türünüzü seçiniz. Kart mı? Nakit mi?").lower()
if tur == "nakit":
    print("Ödemeniz nakit alınacaktır.")
    verilen_ucret = int(input("Hesabı ödemek için ne kadar para verdiğinizi giriniz: "))
    para_ustu = verilen_ucret - toplam_fiyat
    print(f"Para Üstü:  {para_ustu}")
elif tur == "kart":
    print("Ödemeniz karttan alınacaktır.")
    print("dıt")
    time.sleep(1)
    print("Karttan ödeme işleminiz onaylandı")
    print(f"Karttan Çekilen Ücret : {toplam_fiyat}")

s_siparisler = ['{}\t'.format(i) for i in siparisler]
with open("fis.txt", "a+", encoding = "utf-8") as f: 
    f.write("\n")
    f.write("-"*40)
    f.write("\n")
    f.write(str(time.ctime(time.time())))
    lines = [f"\n RESTORANT FİŞİ\n İsim/Soyisim: {isim}\n ToplamFiyat: {toplam_fiyat}\n ÖdemeTürü: {tur}\n "] 
    f.writelines(lines)
    f.writelines(s_siparisler)
    f.write("\n")

soru = input("Geri bildirim anketimize katılmak ister misiniz? ")

if soru == "hayir":
  print("İyi günler dileriz")
  

elif soru == "evet":
  yemekler = int(input("Lütfen yemeklerimizi beş üzerinden değerlendiriniz: "))
  servis = int(input("Lütfen servisimizi beş üzerinden değerlendiriniz: "))
  restorant= int(input("Lütfen restorantımızı beş üzerinden değerlendiriniz: "))
  print("Geri dönüş sağladığınız için teşekkür eder, iyi günler dileriz.")
data= pd.DataFrame({"Yemekler": [yemekler],
        "Servis" : [servis],
        "restorant": [restorant]})

data.to_excel("C:\\Users\\ADA\\Desktop\\samurai.xlsx")
# Out:
# Restorantımıza hoş geldiniz
#   Yemekler         Çeşit : 1       Çeşit : 2       Çeşit : 3
# 0    Pizza  Margarita: 50 TL     Etli: 40 TL   Veggie: 40 TL
# 1  Makarna   Spagetti: 17 TL  Kelebek: 15 TL   Boncuk: 14 TL
# 2    Çorba   Mercimek: 10 TL    Yayla: 10 TL  Tarhana: 14 TL
# 3    Pilav    Tavuklu: 21 TL   Bulgur: 21 TL  Nohutlu: 17 TL
# ----------------------------------------
#     İçecekler  Fiyat
# 0   Coco Cola     20
# 1       Fanta     18
# 2      IceTea     17
# 3  Meyve Suyu     35
# 4       Ayran     15
# İçindekiler:  ['mozarella', 'domates']
#  Sipariş: margarita, Fiyat:50, İçindekiler: ['mozarella', 'domates'], Sosu: istemiyorum
# ----------------------------------------
# Toplam fiyat:  50
# ----------------------------------------
# Sizi bir sürprizimiz ile tanıştırıyoruz, eğer şanslıysanız size tatlı ikram edeceğiz
# Tebrikler tatlı almaya hak kazandınız ve tatlınız : Lokum'dır
# ----------------------------------------
# ----------------------------------------
# ...

# %%
margarita_gider = 40 #Margarita pizzanın gideri
veggie_gider = 30
etli_gider = 30
mercimek_gider = 7
yayla_gider = 8
tarhana_gider= 10
spagetti_gider= 12
kelebek_gider= 10
boncuk_gider = 9
nohut_gider= 13
tavuklu_gider = 17
bulgur_gider= 15
cola_gider = 10
ayran_gider = 7
icet_gider = 12
fanta_gider = 13
meyves_gider = 20

margarita_satış = 50 #Margarita pizzanın satış fiyatı
veggie_satış = 40
etli_satış = 40
mercimek_satış = 10
yayla_satış = 10
tarhana_satış= 14
spagetti_satış= 17
kelebek_satış= 15
boncuk_satış = 14
nohut_satış= 17
tavuklu_satış = 21 
bulgur_satış= 21
cola_satış = 20
ayran_satış = 15
icet_satış = 17 
fanta_satış = 18
meyves_satış = 35

gunluk_kazanc = margarita_satış*margarita - margarita_gider*margarita + veggie_satış*veggi - veggie_gider*veggi + etli_satış*etli - etli_gider*etli + mercimek_satış*mercimek - mercimek_gider*mercimek+ yayla_satış*yayla - yayla_gider*yayla + tarhana_satış*tarhana - tarhana_gider*tarhana + spagetti_satış*spagetti - spagetti_gider*spagetti
+ kelebek_satış*kelebek - kelebek_gider*kelebek + boncuk_satış*boncuk - boncuk_gider*boncuk + nohut_satış*nohutlu - nohut_gider*nohutlu + tavuklu_satış*tavuklu - tavuklu_gider*tavuklu + bulgur_satış*bulgur - bulgur_gider*bulgur + cola_satış*cola - cola_gider*cola 
+ ayran_satış*ayran - ayran_gider*ayran + icet_satış*icetea - icet_gider*icetea + fanta_satış*fanta - fanta_gider*fanta+ meyves_satış*meyvesuyu- meyves_gider*meyvesuyu


kira = int(input("Lütfen kiranızı giriniz:"))
faturalar = int(input("Lütfen faturalarınızın tutarını giriniz:"))
ascı = int(input("Lütfen aşçınızın maaşını giriniz:"))
garson = int(input("Lütfen garsonun maaşını giriniz:"))
alısveris = int(input("Lütfen işletmeniz için yaptığınız alımların ücretini giriniz:"))


aylık_kazanc = (gunluk_kazanc *30) - (kira + ascı + garson+ faturalar + alısveris)


with open ("restorant.txt", "w+", encoding = "utf-8") as res: #w+ dogru mu kontrol edelim, surekli ustune eklemesi gerekiyor her seferinde yeniden baslamasi degil
   lines = [f"GÜNLÜK YAPILAN SATIŞLAR\n Margarita : {margarita}\n VeggiePizza: {veggi}\n EtliPizza: {etli}\n Mercimek: {mercimek}\n Yayla Çorbası: {yayla}\n Tarhana Çorbası: {tarhana}\n Spagetti Makarna: {spagetti}\n Kelebek Makarna: {kelebek}\n Boncuk Makarna: {boncuk}\n Nohutlu Pilav: {nohutlu}\n Tavuklu Pilav: {tavuklu}\n Bulgur Pilavı: {bulgur}\n Coca Cola: {cola}\n Ayran: {ayran}\n IceTea: {icetea}\n Fanta: {fanta}\n MeyveSuyu: {meyvesuyu}\n GİDERLER\n Kira: {kira}\n ÇalışanÜcretleri: {garson +ascı}\n Faturalar: {faturalar}\n Alışveriş:{alısveris} AylıkKazanç: {aylık_kazanc}\n" ]
   res.writelines(lines)
